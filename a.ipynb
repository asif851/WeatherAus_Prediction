# %%
## import necessary modules

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_style('darkgrid')

# %%
df=pd.read_csv('weatherAUS.csv')
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.shape
# Out:
# (145460, 23)

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
plt.subplots(figsize=(20,20))
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
(1485/145460)* 100
# Out:
# 1.0208992162793895

# %%
## Here we will check the percentage of nan values present in each feature
## 1 -step make the list of features which has missing values
features_with_na=[features for features in df.columns if df[features].isnull().sum()>1]
## 2- step print the feature name and the percentage of missing values

for feature in features_with_na:
    print(feature, np.round(df[feature].isnull().mean() * 100, 2),  ' % missing values')
# Out:
# MinTemp 1.02  % missing values
# MaxTemp 0.87  % missing values
# Rainfall 2.24  % missing values
# Evaporation 43.17  % missing values
# Sunshine 48.01  % missing values
# WindGustDir 7.1  % missing values
# WindGustSpeed 7.06  % missing values
# WindDir9am 7.26  % missing values
# WindDir3pm 2.91  % missing values
# WindSpeed9am 1.21  % missing values
# WindSpeed3pm 2.11  % missing values
# Humidity9am 1.82  % missing values
# Humidity3pm 3.1  % missing values
# Pressure9am 10.36  % missing values
# Pressure3pm 10.33  % missing values
# Cloud9am 38.42  % missing values
# Cloud3pm 40.81  % missing values
# Temp9am 1.21  % missing values
# Temp3pm 2.48  % missing values
# RainToday 2.24  % missing values
# RainTomorrow 2.25  % missing values

# %%
df['RainTomorrow'].value_counts()
# Out:
# RainTomorrow
# No     110316
# Yes     31877
# Name: count, dtype: int64

# %%
# 0= no default, 1= default
plt.figure(figsize=(7,5))
sns.countplot(x="RainTomorrow",data=df, order=['Yes','No'],).set_title("RainTomorrow",fontsize=15,fontdict={"weight": "bold"})
# Out:
# Text(0.5, 1.0, 'RainTomorrow')

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#         Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0 2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1 2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2 2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3 2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4 2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  datetime64[ns]
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %% [markdown]
# Since they are many missing values, we need to find the relationship between missing values and Sales Price
# Let's plot some diagram for this relationship

# %%
for feature in features_with_na:
    data = df.copy()
    
    # Create a new column indicating if the value is missing (1) or not (0)
    data[feature] = np.where(data[feature].isnull(), 1, 0)
    
    # Plot the count of missing vs non-missing for each category in SalePrice
    plt.figure(figsize=(8, 5))
    sns.countplot(data=data, x='RainTomorrow', hue=feature)
    plt.title(f"Relationship between missing values in {feature} and RainTomorrow")
    plt.show()

# %%
df.head()
# Out:
#         Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0 2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1 2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2 2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3 2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4 2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# Numerical Variables

# %%
# list of numerical variables
numerical_features = [feature for feature in df.columns if df[feature].dtypes != 'O']

print('Number of numerical variables: ', len(numerical_features))

# visualise the numerical variables
df[numerical_features].head()
# Out:
# Number of numerical variables:  17
#         Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0 2008-12-01     13.4     22.9       0.6          NaN       NaN
# 1 2008-12-02      7.4     25.1       0.0          NaN       NaN
# 2 2008-12-03     12.9     25.7       0.0          NaN       NaN
# 3 2008-12-04      9.2     28.0       0.0          NaN       NaN
# 4 2008-12-05     17.5     32.3       1.0          NaN       NaN
#
#    WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0           44.0          20.0          24.0         71.0         22.0
# 1           44.0           4.0          22.0         44.0         25.0
# 2           46.0          19.0          26.0         38.0         30.0
# 3           24.0          11.0           9.0         45.0         16.0
# 4           41.0           7.0          20.0         82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm
# ...

# %%
## Numerical variables are usually of 2 type
## 1. Continous variable and Discrete Variables

discrete_feature=[feature for feature in numerical_features if len(df[feature].unique())<25]
print("Discrete Variables Count: {}".format(len(discrete_feature)))
# Out:
# Discrete Variables Count: 2

# %%
discrete_feature
# Out:
# ['Cloud9am', 'Cloud3pm']

# %%
df[discrete_feature].head()
# Out:
#    Cloud9am  Cloud3pm
# 0       8.0       NaN
# 1       NaN       NaN
# 2       NaN       2.0
# 3       NaN       NaN
# 4       7.0       8.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for feature in discrete_feature:
    data = df.copy()
    
    # Plot the count of categories in SalePrice for each value of the discrete feature
    plt.figure(figsize=(8, 5))
    sns.countplot(data=data, x=feature, hue='RainTomorrow')
    
    # Set plot labels and title
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.title(f"Relationship between {feature} and RainTomorrow ")
    plt.legend(title='')
    plt.show()

# %%
# Step 1: Identify features with more than 30% missing values
missing_percentage = df.isnull().mean() * 100
features_with_na_30 = missing_percentage[missing_percentage > 30].index

# Step 2: Handle missing values by filling them (e.g., with -1 or 0 for categorical, or mean for numeric)
data = df.copy()
for feature in features_with_na_30:
    # If the feature is categorical, you can fill it with -1 or other placeholder
    if data[feature].dtype == 'object':  # For categorical features
        data[feature] = data[feature].fillna('Missing')  # Use 'Missing' as a placeholder
    else:  # For numeric features
        data[feature] = data[feature].fillna(data[feature].mean())  # Fill with mean or median

# Step 3: Encode 'RainTomorrow' if necessary (assuming 'RainTomorrow' is categorical)
data['RainTomorrow'] = data['RainTomorrow'].map({'Yes': 1, 'No': 0})

# Step 4: Calculate the correlation with 'RainTomorrow' for these features
correlation_matrix = data[features_with_na_30].corrwith(data['RainTomorrow']).sort_values(ascending=False)

# Step 5: Display the correlation values
print("Correlation with RainTomorrow for features with more than 30% missing values:")
print(correlation_matrix)

# Optional: Visualize the correlation values
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.barplot(x=correlation_matrix.index, y=correlation_matrix.values)
plt.xticks(rotation=90)
plt.title("Correlation of Features with RainTomorrow (More than 30% Missing Values)")
plt.ylabel("Correlation Coefficient")
plt.xlabel("Features")
plt.show()
# Out:
# Correlation with RainTomorrow for features with more than 30% missing values:
# Cloud3pm       0.301775
# Cloud9am       0.253772
# Evaporation   -0.089554
# Sunshine      -0.327015
# dtype: float64

# %%
# drop

# Calculate the percentage of missing values for each feature
missing_percentage = df.isnull().mean() * 100

# Filter the features that have more than 30% missing values
features_to_drop = missing_percentage[missing_percentage > 30].index

# Drop the features with more than 30% missing values
dataset_cleaned = df.drop(columns=features_to_drop)

# Optional: Show the dropped features and the cleaned dataset
print("Dropped Features:")
print(features_to_drop)
print("\nCleaned Dataset:")
dataset_cleaned.head()
# Out:
# Dropped Features:
# Index(['Evaporation', 'Sunshine', 'Cloud9am', 'Cloud3pm'], dtype='object')
#
# Cleaned Dataset:
#         Date Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed  \
# 0 2008-12-01   Albury     13.4     22.9       0.6           W           44.0
# 1 2008-12-02   Albury      7.4     25.1       0.0         WNW           44.0
# 2 2008-12-03   Albury     12.9     25.7       0.0         WSW           46.0
# 3 2008-12-04   Albury      9.2     28.0       0.0          NE           24.0
# 4 2008-12-05   Albury     17.5     32.3       1.0           W           41.0
#
#   WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0          W        WNW          20.0          24.0         71.0         22.0
# 1        NNW        WSW           4.0          22.0         44.0         25.0
# 2          W        WSW          19.0          26.0         38.0         30.0
# 3         SE          E          11.0           9.0         45.0         16.0
# ...

# %%
df.shape
# Out:
# (145460, 23)

# %%
## Now lets check for numerical variables the contains missing values
numerical_with_nan=[feature for feature in df.columns if df[feature].isnull().sum()>1 and df[feature].dtypes!='O']

## We will print the numerical nan variables and percentage of missing values

for feature in numerical_with_nan:
    print("{}: {}% missing value".format(feature,np.around(df[feature].isnull().mean(),4)))
# Out:
# MinTemp: 0.0102% missing value
# MaxTemp: 0.0087% missing value
# Rainfall: 0.0224% missing value
# Evaporation: 0.4317% missing value
# Sunshine: 0.4801% missing value
# WindGustSpeed: 0.0706% missing value
# WindSpeed9am: 0.0121% missing value
# WindSpeed3pm: 0.0211% missing value
# Humidity9am: 0.0182% missing value
# Humidity3pm: 0.031% missing value
# Pressure9am: 0.1036% missing value
# Pressure3pm: 0.1033% missing value
# Cloud9am: 0.3842% missing value
# Cloud3pm: 0.4081% missing value
# Temp9am: 0.0121% missing value
# Temp3pm: 0.0248% missing value

# %%
df.shape
# Out:
# (145460, 23)

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
df.head()
# Out:
#         Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0 2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1 2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2 2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3 2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4 2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
df=df.dropna()  #just for now
df.shape
# Out:
# (56420, 23)

# %%
#Encoding the data
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df=df.apply(le.fit_transform)

# %%
# # Dividing dependent and independent variables
X = df.drop("RainTomorrow", axis=1)
y = df["RainTomorrow"]

# %% [markdown]
# Feature Selection
# information gain method

# %%
'''
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_selection import mutual_info_classif

# Assuming the data has already been loaded as DataFrame `X` (features) and `y` (target)
# Replace `X` and `y` with your actual feature DataFrame and target variable.

# Calculate mutual information
importances = mutual_info_classif(X, y)

# Create a dictionary with feature names and their importance values
feature_importance_dict = {feature: importance for feature, importance in zip(X.columns, importances)}

# Print all feature importances
print("Feature Importances:")
for feature, importance in feature_importance_dict.items():
    print(f"'{feature}': {importance}")

# Filter features with importance >= 0.01
filtered_features = {feature: importance for feature, importance in feature_importance_dict.items() if importance >= 0.01}

# Print filtered features
print("\nFeatures with Importance >= 0.01:")
for feature, importance in filtered_features.items():
    print(f"'{feature}': {importance}")

# Create a bar plot for feature importances (not sorted)
plt.figure(figsize=(10, 8))
feat_importances = pd.Series(importances, index=X.columns)
feat_importances.plot(kind="barh", color="skyblue")
plt.title("Feature Importances")
plt.xlabel("Importance Score")
plt.ylabel("Features")
plt.grid(axis="x", linestyle="--", alpha=0.7)
plt.show()
'''
# Out:
# '\nimport pandas as pd\nimport matplotlib.pyplot as plt\nfrom sklearn.feature_selection import mutual_info_classif\n\n# Assuming the data has already been loaded as DataFrame `X` (features) and `y` (target)\n# Replace `X` and `y` with your actual feature DataFrame and target variable.\n\n# Calculate mutual information\nimportances = mutual_info_classif(X, y)\n\n# Create a dictionary with feature names and their importance values\nfeature_importance_dict = {feature: importance for feature, importance in zip(X.columns, importances)}\n\n# Print all feature importances\nprint("Feature Importances:")\nfor feature, importance in feature_importance_dict.items():\n    print(f"\'{feature}\': {importance}")\n\n# Filter features with importance >= 0.01\nfiltered_features = {feature: importance for feature, importance in feature_importance_dict.items() if importance >= 0.01}\n\n# Print filtered features\nprint("\nFeatures with Importance >= 0.01:")\nfor feature, importance in filtered_features.i
# ...

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# Assuming `df` is your DataFrame, and 'target_column' is the binary target column
X = df.drop(columns='RainTomorrow')  # Features
y = df['RainTomorrow']  # Target variable

# Apply Chi-Square Test for feature selection
chi2_selector = SelectKBest(chi2, k='all')  # 'k' can be an integer or 'all'
X_new = chi2_selector.fit_transform(X, y)

# Print the Chi-Square scores for each feature
for i, feature in enumerate(X.columns):
    print(f"'{feature}': {chi2_selector.scores_[i]}")
# Out:
# 'Date': 762.0751300261901
# 'Location': 6.1932452205108195
# 'MinTemp': 9720.72592185628
# 'MaxTemp': 34420.99654830739
# 'Rainfall': 473474.66465634713
# 'Evaporation': 22277.516417937917
# 'Sunshine': 211765.3103382018
# 'WindGustDir': 660.0486096869472
# 'WindGustSpeed': 9286.84282534304
# 'WindDir9am': 222.8961372947831
# 'WindDir3pm': 171.47904930291716
# 'WindSpeed9am': 1082.5852056758213
# 'WindSpeed3pm': 974.5171758495763
# 'Humidity9am': 21563.63289398566
# 'Humidity3pm': 96207.07749109644
# 'Pressure9am': 62328.318824129085
# 'Pressure3pm': 50066.947002478555
# 'Cloud9am': 10922.856761186798
# 'Cloud3pm': 13798.294624354605
# 'Temp9am': 431.7519893453691
# 'Temp3pm': 51321.95043906598
# 'RainToday': 4199.822696085952

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# Assuming `df` is your DataFrame, and 'RainTomorrow' is the binary target column
X = df.drop(columns='RainTomorrow')  # Features
y = df['RainTomorrow']  # Target variable

# Apply Chi-Square Test for feature selection
chi2_selector = SelectKBest(chi2, k='all')  # 'k' can be an integer or 'all'
X_new = chi2_selector.fit_transform(X, y)

# Set a threshold score for feature selection (e.g., 10)
threshold = 10

# Select features based on the threshold score
selected_features = [feature for i, feature in enumerate(X.columns) if chi2_selector.scores_[i] > threshold]

print("Selected Features with Chi-Square Score > 10:")
for feature in selected_features:
    print(f"'{feature}'")
# Out:
# Selected Features with Chi-Square Score > 10:
# 'Date'
# 'MinTemp'
# 'MaxTemp'
# 'Rainfall'
# 'Evaporation'
# 'Sunshine'
# 'WindGustDir'
# 'WindGustSpeed'
# 'WindDir9am'
# 'WindDir3pm'
# 'WindSpeed9am'
# 'WindSpeed3pm'
# 'Humidity9am'
# 'Humidity3pm'
# 'Pressure9am'
# 'Pressure3pm'
# 'Cloud9am'
# 'Cloud3pm'
# 'Temp9am'
# 'Temp3pm'
# 'RainToday'

# %%
# Selected features based on importance
selected_features = ['Cloud9am', 'Cloud3pm', 'Temp3pm', 'RainToday']

# Create a new DataFrame with the selected features
X = X[selected_features]

# Display the first few rows of the new DataFrame
print("New DataFrame with Selected Features:")
X.head()
# Out:
# New DataFrame with Selected Features:
#       Cloud9am  Cloud3pm  Temp3pm  RainToday
# 6049         2         5      280          0
# 6050         1         1      216          0
# 6052         1         6      295          0
# 6053         1         5      302          0
# 6054         1         6      322          0

# %%
X.shape
# Out:
# (56420, 4)

# %%
from sklearn.feature_selection import SelectKBest, chi2
import pandas as pd

# Assuming `df` is your DataFrame, and 'RainTomorrow' is the binary target column
X = df.drop(columns='RainTomorrow')  # Features
y = df['RainTomorrow']  # Target variable

# Apply Chi-Square Test for feature selection
chi2_selector = SelectKBest(chi2, k='all')  # 'k' can be an integer or 'all'
X_new = chi2_selector.fit_transform(X, y)

# Set a threshold score for feature selection (e.g., 10)
threshold = 10

# Select features based on the threshold score
selected_features = [feature for i, feature in enumerate(X.columns) if chi2_selector.scores_[i] > threshold]

# Print Chi-Square Scores for All Features
print("Chi-Square Scores for All Features:")
for i, feature in enumerate(X.columns):
    print(f"'{feature}': {chi2_selector.scores_[i]}")

# Print the selected features
print("\nSelected Features with Chi-Square Score > 10:")
for feature in selected_features:
    print(f"'{feature}'")
# Out:
# Chi-Square Scores for All Features:
# 'Date': 762.0751300261901
# 'Location': 6.1932452205108195
# 'MinTemp': 9720.72592185628
# 'MaxTemp': 34420.99654830739
# 'Rainfall': 473474.66465634713
# 'Evaporation': 22277.516417937917
# 'Sunshine': 211765.3103382018
# 'WindGustDir': 660.0486096869472
# 'WindGustSpeed': 9286.84282534304
# 'WindDir9am': 222.8961372947831
# 'WindDir3pm': 171.47904930291716
# 'WindSpeed9am': 1082.5852056758213
# 'WindSpeed3pm': 974.5171758495763
# 'Humidity9am': 21563.63289398566
# 'Humidity3pm': 96207.07749109644
# 'Pressure9am': 62328.318824129085
# 'Pressure3pm': 50066.947002478555
# 'Cloud9am': 10922.856761186798
# 'Cloud3pm': 13798.294624354605
# 'Temp9am': 431.7519893453691
# 'Temp3pm': 51321.95043906598
# 'RainToday': 4199.822696085952
#
# Selected Features with Chi-Square Score > 10:
# 'Date'
# 'MinTemp'
# 'MaxTemp'
# 'Rainfall'
# 'Evaporation'
# 'Sunshine'
# 'WindGustDir'
# 'WindGustSpeed'
# 'WindDir9am'
# 'WindDir3pm'
# 'WindSpeed9am'
# 'WindSpeed3pm'
# ...

# %%
from sklearn.feature_selection import SelectKBest, chi2
import pandas as pd

# Assuming `df` is your DataFrame, and 'RainTomorrow' is the binary target column
X = df.drop(columns='RainTomorrow')  # Features
y = df['RainTomorrow']  # Target variable

# Apply Chi-Square Test for feature selection
chi2_selector = SelectKBest(chi2, k='all')  # 'k' can be an integer or 'all'
X_new = chi2_selector.fit_transform(X, y)

# Set a threshold score for feature selection (e.g., 10)
threshold = 10

# Select features based on the threshold score
selected_features = [feature for i, feature in enumerate(X.columns) if chi2_selector.scores_[i] > threshold]

# Print Chi-Square Scores for All Features
print("Chi-Square Scores for All Features:")
for i, feature in enumerate(X.columns):
    print(f"'{feature}': {chi2_selector.scores_[i]}")

# Print the selected features
print("\nSelected Features with Chi-Square Score > 10:")
for feature in selected_features:
    print(f"'{feature}'")
# Out:
# Chi-Square Scores for All Features:
# 'Date': 762.0751300261901
# 'Location': 6.1932452205108195
# 'MinTemp': 9720.72592185628
# 'MaxTemp': 34420.99654830739
# 'Rainfall': 473474.66465634713
# 'Evaporation': 22277.516417937917
# 'Sunshine': 211765.3103382018
# 'WindGustDir': 660.0486096869472
# 'WindGustSpeed': 9286.84282534304
# 'WindDir9am': 222.8961372947831
# 'WindDir3pm': 171.47904930291716
# 'WindSpeed9am': 1082.5852056758213
# 'WindSpeed3pm': 974.5171758495763
# 'Humidity9am': 21563.63289398566
# 'Humidity3pm': 96207.07749109644
# 'Pressure9am': 62328.318824129085
# 'Pressure3pm': 50066.947002478555
# 'Cloud9am': 10922.856761186798
# 'Cloud3pm': 13798.294624354605
# 'Temp9am': 431.7519893453691
# 'Temp3pm': 51321.95043906598
# 'RainToday': 4199.822696085952
#
# Selected Features with Chi-Square Score > 10:
# 'Date'
# 'MinTemp'
# 'MaxTemp'
# 'Rainfall'
# 'Evaporation'
# 'Sunshine'
# 'WindGustDir'
# 'WindGustSpeed'
# 'WindDir9am'
# 'WindDir3pm'
# 'WindSpeed9am'
# 'WindSpeed3pm'
# ...

# %%
'''
# Sampling
from imblearn.over_sampling import SMOTE 
from collections import Counter

sampler = SMOTE()
X, y = sampler.fit_resample(X, y)

print('SMOTE {}'.format(Counter(y)))
'''
# Out:
# "\n# Sampling\nfrom imblearn.over_sampling import SMOTE \nfrom collections import Counter\n\nsampler = SMOTE()\nX, y = sampler.fit_resample(X, y)\n\nprint('SMOTE {}'.format(Counter(y)))\n"

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# Feature Scaling

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression  

classifier= LogisticRegression(random_state=0)  
lr_model=classifier.fit(X_train, y_train)
y_pred=lr_model.predict(X_test)

# %%
# Accuracy = TP+TN/TP+FP+FN+TN
# Precision = TP/TP+FP
# Recall = TP/TP+FN
#F1 Score = 2*(Recall * Precision) / (Recall + Precision)


from sklearn.metrics import classification_report, confusion_matrix 
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88     10979
#            1       0.62      0.32      0.42      3126
#
#     accuracy                           0.81     14105
#    macro avg       0.72      0.63      0.65     14105
# weighted avg       0.78      0.81      0.78     14105

# %%
x_axis_labels = ['No','Yes']
y_axis_labels = ['No','Yes']

confusion_m=confusion_matrix(y_test,y_pred)
sns.heatmap(confusion_m, annot=True,cmap='Greens', xticklabels=x_axis_labels, yticklabels=y_axis_labels)

plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
# Out:
# Text(50.722222222222214, 0.5, 'Actual Label')

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

clf= KNeighborsClassifier(n_neighbors=25)

# Train the model using the training sets
knn_model=clf.fit(X_train,y_train)

y_pred=knn_model.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88     10979
#            1       0.61      0.34      0.44      3126
#
#     accuracy                           0.81     14105
#    macro avg       0.72      0.64      0.66     14105
# weighted avg       0.78      0.81      0.78     14105

# %%
x_axis_labels = ['No','Yes']
y_axis_labels = ['No','Yes']

confusion_m=confusion_matrix(y_test,y_pred)
sns.heatmap(confusion_m, annot=True,cmap='viridis', xticklabels=x_axis_labels, yticklabels=y_axis_labels)

plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
# Out:
# Text(50.722222222222214, 0.5, 'Actual Label')

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Initialize an empty list to store accuracy scores
accuracy_scores = []

# Loop over a range of k values
for k in range(1, 51):  # Testing k values from 1 to 50
    clf = KNeighborsClassifier(n_neighbors=k)
    clf.fit(X_train, y_train)  # Train the model
    
    # Predict on the test set
    y_pred = clf.predict(X_test)
    
    # Calculate the accuracy and append it to the list
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_scores.append((k, accuracy))

# Find the k value with the highest accuracy
best_k, best_accuracy = max(accuracy_scores, key=lambda x: x[1])

# Print the results
print(f"Optimal k: {best_k} with accuracy: {best_accuracy}")

# Optional: Visualize accuracy scores
import matplotlib.pyplot as plt

k_values = [score[0] for score in accuracy_scores]
accuracies = [score[1] for score in accuracy_scores]

plt.plot(k_values, accuracies, marker='o')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Number of Neighbors (k)')
plt.show()
# Out:
# Optimal k: 42 with accuracy: 0.8095001772421128

# %%
from sklearn.neighbors import KNeighborsClassifier

clf= KNeighborsClassifier(n_neighbors=47)

# Train the model using the training sets
knn_model=clf.fit(X_train,y_train)

y_pred=knn_model.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91     24060
#            1       0.76      0.43      0.55      6868
#
#     accuracy                           0.84     30928
#    macro avg       0.81      0.70      0.73     30928
# weighted avg       0.83      0.84      0.83     30928
